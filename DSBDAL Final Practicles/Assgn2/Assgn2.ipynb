# %% [markdown]
# # Assignment 2

# %% [markdown]
# Name : Ghanashyam Patil
# Roll No : 31162
# Subject : DSBDAL
#
# Problem Statement :
# Perform the following operations using Python on any open-source dataset (e.g., data.csv)
# 1. Import all the required Python Libraries.
# 2. Load the Dataset into pandas’ data frame.
# 3. Data Preprocessing: check for missing values in the data using pandas isnull (),head(),tail(), info() describe() function to get some initial statistics. Provide variable descriptions. Types of variables etc. Check the dimensions of the data frame.
# 4. Turn categorical variables into quantitative variables in Python.

# %%
import numpy as np
import pandas  as pd

# %%
df = pd.read_csv('../Databases/Workout.csv')
df.head()
# Out:
#   Body Part Type of Muscle                   Workout Sets Reps per Set
# 0     Chest    Upper Chest    Incline dumbbell press  3-4         8-12
# 1     Chest    Upper Chest  Incline cable crossovers  3-4        10-15
# 2     Chest    Upper Chest    Incline dumbbell flyes  3-4        10-15
# 3     Chest    Lower Chest    Decline dumbbell press  3-4         8-12
# 4     Chest    Lower Chest  Decline cable crossovers  3-4        10-15

# %%
df.shape
# Out:
# (52, 5)

# %%
df.isnull()
# Out:
#     Body Part  Type of Muscle  Workout   Sets  Reps per Set
# 0       False           False    False  False         False
# 1       False           False    False  False         False
# 2       False           False    False  False         False
# 3       False           False    False  False         False
# 4       False           False    False  False         False
# 5       False           False    False  False         False
# 6       False           False    False  False         False
# 7       False           False    False  False         False
# 8       False           False    False  False         False
# 9       False           False    False  False         False
# 10      False           False    False  False         False
# 11      False           False    False  False         False
# 12      False           False    False  False         False
# 13      False           False    False  False         False
# 14      False           False    False  False         False
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52 entries, 0 to 51
# Data columns (total 5 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Body Part       52 non-null     object
#  1   Type of Muscle  52 non-null     object
#  2   Workout         52 non-null     object
#  3   Sets            52 non-null     object
#  4   Reps per Set    52 non-null     object
# dtypes: object(5)
# memory usage: 2.2+ KB

# %% [markdown]
# # Turn categorical variables into quantitative variables in Python.

# %%
df1 = pd.get_dummies(df['Sets'])
new_df = pd.concat([df,df1], axis=1)
new_df
# Out:
#     Body Part   Type of Muscle                      Workout
# 0       Chest      Upper Chest       Incline dumbbell press  \
# 1       Chest      Upper Chest     Incline cable crossovers
# 2       Chest      Upper Chest       Incline dumbbell flyes
# 3       Chest      Lower Chest       Decline dumbbell press
# 4       Chest      Lower Chest     Decline cable crossovers
# 5       Chest      Lower Chest       Decline dumbbell flyes
# 6       Chest  Chest Isolation                  Chest flyes
# 7       Chest  Chest Isolation             Cable crossovers
# 8       Chest  Chest Isolation               Dumbbell flyes
# 9        Back            Upper                     Pull-ups
# 10       Back            Upper                 Barbell rows
# 11       Back            Upper                Dumbbell rows
# 12       Back            Upper            Seated cable rows
# 13       Back            Lower               Bent-over rows
# 14       Back            Lower              Hyperextensions
# ...

# %%
#broken the column workout in to different columns of distinct values
new_df.drop(columns=['Sets'])
# Out:
#     Body Part   Type of Muscle                      Workout Reps per Set
# 0       Chest      Upper Chest       Incline dumbbell press         8-12  \
# 1       Chest      Upper Chest     Incline cable crossovers        10-15
# 2       Chest      Upper Chest       Incline dumbbell flyes        10-15
# 3       Chest      Lower Chest       Decline dumbbell press         8-12
# 4       Chest      Lower Chest     Decline cable crossovers        10-15
# 5       Chest      Lower Chest       Decline dumbbell flyes        10-15
# 6       Chest  Chest Isolation                  Chest flyes        10-15
# 7       Chest  Chest Isolation             Cable crossovers        10-15
# 8       Chest  Chest Isolation               Dumbbell flyes        10-15
# 9        Back            Upper                     Pull-ups         8-12
# 10       Back            Upper                 Barbell rows         8-12
# 11       Back            Upper                Dumbbell rows         8-12
# ...

# %%
new_df['3 sets of 10-15 reps per leg']=new_df['3 sets of 10-15 reps per leg'].astype('int64')
new_df['3 sets of 10-15 reps per side']=new_df['3 sets of 10-15 reps per side'].astype('int64')
new_df['3 sets of 15-20 reps']=new_df['3 sets of 15-20 reps'].astype('int64')
new_df['3-4']=new_df['3-4'].astype('int64')
new_df['3-4']=new_df['3-5'].astype('int64')
new_df
# Out:
#     Body Part   Type of Muscle                      Workout
# 0       Chest      Upper Chest       Incline dumbbell press  \
# 1       Chest      Upper Chest     Incline cable crossovers
# 2       Chest      Upper Chest       Incline dumbbell flyes
# 3       Chest      Lower Chest       Decline dumbbell press
# 4       Chest      Lower Chest     Decline cable crossovers
# 5       Chest      Lower Chest       Decline dumbbell flyes
# 6       Chest  Chest Isolation                  Chest flyes
# 7       Chest  Chest Isolation             Cable crossovers
# 8       Chest  Chest Isolation               Dumbbell flyes
# 9        Back            Upper                     Pull-ups
# 10       Back            Upper                 Barbell rows
# 11       Back            Upper                Dumbbell rows
# 12       Back            Upper            Seated cable rows
# 13       Back            Lower               Bent-over rows
# 14       Back            Lower              Hyperextensions
# ...
