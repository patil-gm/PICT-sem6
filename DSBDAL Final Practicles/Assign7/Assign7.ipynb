# %% [markdown]
# # Assignment 7
#
# Name : Ghanashyam Patil
# Roll No : 31162
# Subject : DSBDAL
#
# Problem Statement :
# Create a Linear Regression Model using Python/R to predict home prices.
# The objective is to predict the value of prices of the house using the given features in the dataset.

# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt 
import seaborn as sns 
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score, mean_absolute_error,accuracy_score

# %%
data=pd.read_csv('../Databases/BostonHousing.csv')
data
# Out:
#         crim    zn  indus  chas    nox     rm   age     dis  rad  tax
# 0    0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296  \
# 1    0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242
# 2    0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242
# 3    0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222
# 4    0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222
# ..       ...   ...    ...   ...    ...    ...   ...     ...  ...  ...
# 501  0.06263   0.0  11.93     0  0.573  6.593  69.1  2.4786    1  273
# 502  0.04527   0.0  11.93     0  0.573  6.120  76.7  2.2875    1  273
# 503  0.06076   0.0  11.93     0  0.573  6.976  91.0  2.1675    1  273
# 504  0.10959   0.0  11.93     0  0.573  6.794  89.3  2.3889    1  273
# 505  0.04741   0.0  11.93     0  0.573  6.030  80.8  2.5050    1  273
#
#      ptratio       b  lstat  medv
# 0       15.3  396.90   4.98  24.0
# 1       17.8  396.90   9.14  21.6
# ...

# %% [markdown]
# # Removing NULL values

# %%
data.fillna(0)
data.head()
# Out:
#       crim    zn  indus  chas    nox     rm   age     dis  rad  tax  ptratio
# 0  0.00632  18.0   2.31     0  0.538  6.575  65.2  4.0900    1  296     15.3  \
# 1  0.02731   0.0   7.07     0  0.469  6.421  78.9  4.9671    2  242     17.8
# 2  0.02729   0.0   7.07     0  0.469  7.185  61.1  4.9671    2  242     17.8
# 3  0.03237   0.0   2.18     0  0.458  6.998  45.8  6.0622    3  222     18.7
# 4  0.06905   0.0   2.18     0  0.458  7.147  54.2  6.0622    3  222     18.7
#
#         b  lstat  medv
# 0  396.90   4.98  24.0
# 1  396.90   9.14  21.6
# 2  392.83   4.03  34.7
# 3  394.63   2.94  33.4
# 4  396.90   5.33  36.2

# %% [markdown]
# # Linear Regression Model

# %%
# Select the features (X) and target variable (y)
X=data["rm"]

y = data['medv']

# %%
# Split the data into training and testing sets
X_train, X_test, y_train, y_test = train_test_split(data, y, test_size=0.3, random_state=5)

# %%
# Create a linear regression model
model = LinearRegression()

# %%
# Train the model on the training data
model.fit(X_train.to_numpy(), y_train)
# Out:
# LinearRegression()

# %%
# Make predictions on the testing data
y_pred = model.predict(X_test)
print("Predicted Prices :",y_pred)
# Out:
# Predicted Prices : [37.6 27.9 22.6 13.8 35.2 10.4 23.9 29.  22.8 23.2 33.2 19.  20.3 36.1
#  24.4 17.2 17.9 19.6 19.7 15.   8.1 23.  44.8 23.1 32.2 10.8 23.1 21.2
#  22.2 24.1 17.3  7.  12.7 17.8 26.4 19.6 25.1  8.3 48.8 34.9 13.8 14.4
#  30.1 12.7 27.1 24.8  7.  20.5 21.5 14.  20.4 22.2 21.4 13.5 19.4 24.7
#  43.8 14.1 28.6 19.7 16.8 23.2 16.2 41.3 22.7  8.3 18.4 24.7 21.7 20.6
#  16.7 22.1 19.4 27.5 27.9 30.1 17.4 15.4 31.  14.2 19.6 50.  21.7 11.7
#  19.4 13.  17.5  9.7 20.3 18.6 50.  19.6 21.4 18.4 22.6 25.  15.6 26.6
#  22.4 13.1 23.  24.5 13.1 50.   8.8 20.6 12.1 50.  24.1 16.1 23.9 24.3
#  13.1 30.3 15.2 13.8 26.4 16.6 18.9 17.6 18.7 33.4 20.7 17.1 23.4 26.5
#  21.4 21.5 19.2 50.  50.  23.  10.5 17.8 10.9 21.  13.8 10.5 22.2 30.5
#  19.4 15.6 20.2 19.3 34.6 50.  24.  18.7 19.8 22.5 13.3 50. ]
# /opt/homebrew/Cellar/jupyterlab/4.0.0/libexec/lib/python3.11/site-packages/sklearn/base.py:432: UserWarning: X has feature names, but LinearRegression was fitted without feature names
# ...

# %%
# Evaluate the model's performance
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
mae = mean_absolute_error(y_test, y_pred)
print("Mean Squared Error:", mse)
print("r2 score:", mse)
print("Mean Absolute Error:", mse)
# Out:
# Mean Squared Error: 1.7990803323465406e-27
# r2 score: 1.7990803323465406e-27
# Mean Absolute Error: 1.7990803323465406e-27

# %%
sns.regplot(data=data,x=X,y=y)
# Out:
# <Axes: xlabel='rm', ylabel='medv'>
