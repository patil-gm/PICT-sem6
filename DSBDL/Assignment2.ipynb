# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/home/pict/31162/academic-performance.csv")

# %%
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0       62.0       98.0
# 1        2    Reyansh      M     IT        58.0       62.0       83.0
# 2        3      Aarav      M     IT        57.0      -20.0      100.0
# 3        4     Atharv      M     IT        60.0       89.0       83.0
# 4        5     Vivaan      M   Comp        85.0       90.0        NaN
# 5        6      Advik      M   ENTC        94.0       99.0       84.0
# 6        7       Ansh      M   ENTC        98.0       88.0       95.0
# 7        8     Ishaan      M   ENTC        75.0       66.0       51.0
# 8        9      Dhruv      M   ENTC        63.0        NaN        NaN
# 9       10  Siddharth      M   ENTC        96.0       67.0       78.0
# 10      11     Vihaan      M   ENTC        82.0       54.0       70.0
# 11      12        NaN      M     IT        75.0       64.0       67.0
# ...

# %%
df.head()
# Out:
#    Rollno      Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0       1  Mohammed      M   Comp        72.0       62.0       98.0
# 1       2   Reyansh      M     IT        58.0       62.0       83.0
# 2       3     Aarav      M     IT        57.0      -20.0      100.0
# 3       4    Atharv      M     IT        60.0       89.0       83.0
# 4       5    Vivaan      M   Comp        85.0       90.0        NaN
#
#    EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# 0       63.0       89.0       36.0          368        73.6
# 1       83.0       88.0       34.0          350        70.0
# 2        NaN       56.0       36.0          192        38.4
# 3       70.0       33.0       23.0          298        59.6
# 4       78.0       23.0       56.0          247        49.4

# %%
df.tail()
# Out:
#     Rollno     Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 15      16   Saanvi      F   Comp        66.0       90.0       95.0
# 16      17  Zaranew      F   Comp        93.0       54.0        NaN
# 17      18    Inaya      F   Comp        74.0       67.0       93.0
# 18      19    Aarya      F   Comp        72.0       88.0       84.0
# 19      20      NaN      F   Comp        53.0       76.0       81.0
#
#     EM1_marks  PPS_marks  SME_marks  Total Marks  Percentage
# 15       67.0       99.0       77.0          428        85.6
# 16       75.0       90.0       65.0          284        56.8
# 17       93.0       87.0       99.0          439        87.8
# 18       81.0       80.0       45.0          378        75.6
# 19       93.0       65.0       23.0          338        67.6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20 entries, 0 to 19
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Rollno       20 non-null     int64
#  1   Name         18 non-null     object
#  2   Gender       20 non-null     object
#  3   Branch       20 non-null     object
#  4   Attendence   20 non-null     float64
#  5   Phy_marks    19 non-null     float64
#  6   Che_marks    17 non-null     float64
#  7   EM1_marks    18 non-null     float64
#  8   PPS_marks    19 non-null     float64
#  9   SME_marks    20 non-null     float64
#  10  Total Marks  20 non-null     int64
#  11  Percentage   20 non-null     float64
# dtypes: float64(7), int64(2), object(3)
# memory usage: 2.0+ KB

# %%
df.describe()
# Out:
#          Rollno  Attendence  Phy_marks   Che_marks   EM1_marks  PPS_marks  \
# count  20.00000   20.000000  19.000000   17.000000   18.000000  19.000000
# mean   10.50000   75.100000  63.421053   80.764706   83.444444  60.736842
# std     5.91608   14.660724  34.940133   13.690916   11.078449  43.598983
# min     1.00000   53.000000 -34.000000   51.000000   63.000000 -99.000000
# 25%     5.75000   63.750000  59.000000   70.000000   75.750000  56.000000
# 50%    10.50000   73.000000  67.000000   83.000000   83.000000  66.000000
# 75%    15.25000   87.000000  88.000000   93.000000   93.000000  87.500000
# max    20.00000   98.000000  99.000000  100.000000  100.000000  99.000000
#
#        SME_marks  Total Marks  Percentage
# count  20.000000    20.000000   20.000000
# mean   62.700000   327.150000   65.430000
# std    24.891554    78.951867   15.790373
# min    23.000000   192.000000   38.400000
# 25%    42.750000   279.750000   55.950000
# 50%    60.500000   338.000000   67.600000
# ...

# %%
df.shape
# Out:
# (20, 12)

# %%
df.isnull()
# Out:
#     Rollno   Name  Gender  Branch  Attendence  Phy_marks  Che_marks  \
# 0    False  False   False   False       False      False      False
# 1    False  False   False   False       False      False      False
# 2    False  False   False   False       False      False      False
# 3    False  False   False   False       False      False      False
# 4    False  False   False   False       False      False       True
# 5    False  False   False   False       False      False      False
# 6    False  False   False   False       False      False      False
# 7    False  False   False   False       False      False      False
# 8    False  False   False   False       False       True       True
# 9    False  False   False   False       False      False      False
# 10   False  False   False   False       False      False      False
# 11   False   True   False   False       False      False      False
# 12   False  False   False   False       False      False      False
# ...

# %%
df.isnull().sum()
# Out:
# Rollno         0
# Name           2
# Gender         0
# Branch         0
# Attendence     0
# Phy_marks      1
# Che_marks      3
# EM1_marks      2
# PPS_marks      1
# SME_marks      0
# Total Marks    0
# Percentage     0
# dtype: int64

# %%
df["Name"].fillna(df["Name"].value_counts().index[0],inplace=True)

# %%
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0       62.0       98.0
# 1        2    Reyansh      M     IT        58.0       62.0       83.0
# 2        3      Aarav      M     IT        57.0      -20.0      100.0
# 3        4     Atharv      M     IT        60.0       89.0       83.0
# 4        5     Vivaan      M   Comp        85.0       90.0        NaN
# 5        6      Advik      M   ENTC        94.0       99.0       84.0
# 6        7       Ansh      M   ENTC        98.0       88.0       95.0
# 7        8     Ishaan      M   ENTC        75.0       66.0       51.0
# 8        9      Dhruv      M   ENTC        63.0        NaN        NaN
# 9       10  Siddharth      M   ENTC        96.0       67.0       78.0
# 10      11     Vihaan      M   ENTC        82.0       54.0       70.0
# 11      12   Mohammed      M     IT        75.0       64.0       67.0
# ...

# %%
def fill_null(dataframe,numcol):
    dataframe[numcol].fillna(dataframe[numcol].mean(),inplace=True)

# %%
cols = df.iloc[0:,4:]

# %%
cols
# Out:
#     Attendence  Phy_marks  Che_marks  EM1_marks  PPS_marks  SME_marks  \
# 0         72.0       62.0       98.0       63.0       89.0       36.0
# 1         58.0       62.0       83.0       83.0       88.0       34.0
# 2         57.0      -20.0      100.0        NaN       56.0       36.0
# 3         60.0       89.0       83.0       70.0       33.0       23.0
# 4         85.0       90.0        NaN       78.0       23.0       56.0
# 5         94.0       99.0       84.0      100.0       56.0       99.0
# 6         98.0       88.0       95.0       81.0       78.0       78.0
# 7         75.0       66.0       51.0       83.0      -99.0       76.0
# 8         63.0        NaN        NaN       97.0       56.0       55.0
# 9         96.0       67.0       78.0       95.0        NaN       98.0
# 10        82.0       54.0       70.0       88.0       55.0       56.0
# 11        75.0       64.0       67.0       71.0       66.0       87.0
# ...

# %%
for col in cols:
    fill_null(df,col)

# %%
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks   Che_marks  \
# 0        1   Mohammed      M   Comp        72.0  62.000000   98.000000
# 1        2    Reyansh      M     IT        58.0  62.000000   83.000000
# 2        3      Aarav      M     IT        57.0 -20.000000  100.000000
# 3        4     Atharv      M     IT        60.0  89.000000   83.000000
# 4        5     Vivaan      M   Comp        85.0  90.000000   80.764706
# 5        6      Advik      M   ENTC        94.0  99.000000   84.000000
# 6        7       Ansh      M   ENTC        98.0  88.000000   95.000000
# 7        8     Ishaan      M   ENTC        75.0  66.000000   51.000000
# 8        9      Dhruv      M   ENTC        63.0  63.421053   80.764706
# 9       10  Siddharth      M   ENTC        96.0  67.000000   78.000000
# 10      11     Vihaan      M   ENTC        82.0  54.000000   70.000000
# 11      12   Mohammed      M     IT        75.0  64.000000   67.000000
# ...

# %%
df.isnull().sum()
# Out:
# Rollno         0
# Name           0
# Gender         0
# Branch         0
# Attendence     0
# Phy_marks      0
# Che_marks      0
# EM1_marks      0
# PPS_marks      0
# SME_marks      0
# Total Marks    0
# Percentage     0
# dtype: int64

# %%
# outliers

# %%
# Scatterplot

# %%
for col in cols:
    sns.boxplot(df[col])
    plt.show(block=True)
# Out:
# /usr/local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# /usr/local/lib/python3.8/site-packages/seaborn/_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
for col in cols:
    df.boxplot(col)

# %%
# IQR

# %%
q1 = np.percentile(df["Phy_marks"],25,interpolation='midpoint')
q3 = np.percentile(df["Phy_marks"],75,interpolation='midpoint')
iqr = q3-q1

phyupper = np.where(df["Phy_marks"]>=(q3+1.5*iqr))
phylower = np.where(df["Phy_marks"]<=(q1-1.5*iqr))
print("Phy_marks",phylower[0],phyupper[0])
# Out:
# Phy_marks [ 2 13] []

# %%
q1 = np.percentile(df["Che_marks"],25,interpolation='midpoint')
q3 = np.percentile(df["Che_marks"],75,interpolation='midpoint')
iqr = q3-q1

cupper = np.where(df["Che_marks"]>=(q3+1.5*iqr))
clower = np.where(df["Che_marks"]<=(q1-1.5*iqr))
print("Che_marks",clower[0],cupper[0])
# Out:
# Che_marks [7] []

# %%
q1 = np.percentile(df["PPS_marks"],25,interpolation='midpoint')
q3 = np.percentile(df["PPS_marks"],75,interpolation='midpoint')
iqr = q3-q1

ppsupper = np.where(df["PPS_marks"]>=(q3+1.5*iqr))
ppslower = np.where(df["PPS_marks"]<=(q1-1.5*iqr))
print("PPS_marks",ppslower[0],ppsupper[0])
# Out:
# PPS_marks [7] []

# %%
df.drop(ppslower[0],inplace=True)

# %%
df.drop(phylower[0],inplace=True)

# %%
df.shape
# Out:
# (17, 12)

# %%
# Z-Score

# %%
mean = np.mean(df["Che_marks"])
std = np.std(df["Che_marks"])
threshold = -2
outliers = []

# %%
for i in df["Che_marks"]:
    z = (i-mean)/std
    if z<threshold:
        outliers.append(i)

print(outliers)
# Out:
# [60.0]

# %%
plt.scatter(df["Rollno"],df["Che_marks"])

# %%
df.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df
# Out:
#     Rollno       Name Gender Branch  Attendence  Phy_marks  Che_marks  \
# 0        1   Mohammed      M   Comp        72.0  62.000000  98.000000
# 1        2    Reyansh      M     IT        58.0  62.000000  83.000000
# 3        4     Atharv      M     IT        60.0  89.000000  83.000000
# 4        5     Vivaan      M   Comp        85.0  90.000000  80.764706
# 5        6      Advik      M   ENTC        94.0  99.000000  84.000000
# 6        7       Ansh      M   ENTC        98.0  88.000000  95.000000
# 8        9      Dhruv      M   ENTC        63.0  63.421053  80.764706
# 9       10  Siddharth      M   ENTC        96.0  67.000000  78.000000
# 10      11     Vihaan      M   ENTC        82.0  54.000000  70.000000
# 11      12   Mohammed      M     IT        75.0  64.000000  67.000000
# 12      13     Aarush      M     IT        67.0  56.000000  81.000000
# 14      15     Maryam      F     IT        64.0  87.000000  60.000000
# ...

# %%
df_minmax = df.copy()
df_minmax = df_minmax.iloc[0:,4:]

df_minmax
# Out:
#     Attendence  Phy_marks  Che_marks   EM1_marks  PPS_marks  SME_marks  \
# 0         72.0  62.000000  98.000000   63.000000  89.000000       36.0
# 1         58.0  62.000000  83.000000   83.000000  88.000000       34.0
# 3         60.0  89.000000  83.000000   70.000000  33.000000       23.0
# 4         85.0  90.000000  80.764706   78.000000  23.000000       56.0
# 5         94.0  99.000000  84.000000  100.000000  56.000000       99.0
# 6         98.0  88.000000  95.000000   81.000000  78.000000       78.0
# 8         63.0  63.421053  80.764706   97.000000  56.000000       55.0
# 9         96.0  67.000000  78.000000   95.000000  60.736842       98.0
# 10        82.0  54.000000  70.000000   88.000000  55.000000       56.0
# 11        75.0  64.000000  67.000000   71.000000  66.000000       87.0
# 12        67.0  56.000000  81.000000   83.444444  90.000000       55.0
# 14        64.0  87.000000  60.000000   90.000000  65.000000       90.0
# ...

# %%
for col in df_minmax:
    df_minmax[col] = (df_minmax[col]-df_minmax[col].min())/(df_minmax[col].max()-df_minmax[col].min())

# %%
df_minmax
# Out:
#     Attendence  Phy_marks  Che_marks  EM1_marks  PPS_marks  SME_marks  \
# 0     0.422222   0.177778   1.000000   0.000000   0.868421   0.171053
# 1     0.111111   0.177778   0.605263   0.540541   0.855263   0.144737
# 3     0.155556   0.777778   0.605263   0.189189   0.131579   0.000000
# 4     0.711111   0.800000   0.546440   0.405405   0.000000   0.434211
# 5     0.911111   1.000000   0.631579   1.000000   0.434211   1.000000
# 6     1.000000   0.755556   0.921053   0.486486   0.723684   0.723684
# 8     0.222222   0.209357   0.546440   0.918919   0.434211   0.421053
# 9     0.955556   0.288889   0.473684   0.864865   0.496537   0.986842
# 10    0.644444   0.000000   0.263158   0.675676   0.421053   0.434211
# 11    0.488889   0.222222   0.184211   0.216216   0.565789   0.842105
# 12    0.311111   0.044444   0.552632   0.552553   0.881579   0.421053
# 14    0.244444   0.733333   0.000000   0.729730   0.552632   0.881579
# ...

# %%
df_minmax.plot.bar()
# Out:
# <AxesSubplot:>

# %%
df_z = df.copy()
df_z = df_z.iloc[0:,4:]

df_z
# Out:
#     Attendence  Phy_marks  Che_marks   EM1_marks  PPS_marks  SME_marks  \
# 0         72.0  62.000000  98.000000   63.000000  89.000000       36.0
# 1         58.0  62.000000  83.000000   83.000000  88.000000       34.0
# 3         60.0  89.000000  83.000000   70.000000  33.000000       23.0
# 4         85.0  90.000000  80.764706   78.000000  23.000000       56.0
# 5         94.0  99.000000  84.000000  100.000000  56.000000       99.0
# 6         98.0  88.000000  95.000000   81.000000  78.000000       78.0
# 8         63.0  63.421053  80.764706   97.000000  56.000000       55.0
# 9         96.0  67.000000  78.000000   95.000000  60.736842       98.0
# 10        82.0  54.000000  70.000000   88.000000  55.000000       56.0
# 11        75.0  64.000000  67.000000   71.000000  66.000000       87.0
# 12        67.0  56.000000  81.000000   83.444444  90.000000       55.0
# 14        64.0  87.000000  60.000000   90.000000  65.000000       90.0
# ...

# %%
for col in df_z:
    df_z[col] = (df_z[col]-df_z[col].mean())/df_z[col].std()

# %%
df_z
# Out:
#     Attendence  Phy_marks  Che_marks  EM1_marks  PPS_marks  SME_marks  \
# 0    -0.198710  -0.788485   1.597984  -1.789415   0.926467  -1.047378
# 1    -1.183980  -0.788485   0.098252   0.013552   0.879065  -1.124126
# 3    -1.043227   0.999445   0.098252  -1.158377  -1.728046  -1.546237
# 4     0.716183   1.065665  -0.125237  -0.437190  -2.202066  -0.279903
# 5     1.349571   1.661642   0.198234   1.546073  -0.637799   1.370170
# 6     1.631077   0.933226   1.298038  -0.166745   0.405045   0.564320
# 8    -0.832098  -0.694384  -0.125237   1.275628  -0.637799  -0.318277
# 9     1.490324  -0.457387  -0.401658   1.095332  -0.413263   1.331796
# 10    0.505054  -1.318243  -1.201515   0.464293  -0.685201  -0.279903
# 11    0.012419  -0.656046  -1.501461  -1.068228  -0.163779   0.909684
# 12   -0.550592  -1.185803  -0.101712   0.053618   0.973869  -0.318277
# 14   -0.761721   0.867006  -2.201336   0.644590  -0.211181   1.024806
# ...

# %%
df_z.plot.bar()
# Out:
# <AxesSubplot:>
